# %% [markdown]
# # Pre-intemediate Pandas
# ## Most of the information comes from the pandas kaggle course
# > [Kaggle pandas course](https://www.kaggle.com/learn/pandas)
#
# > **data** is stored in ./data/wines
# ***
#
# 1. [Creating](#Creating)
#
# 2. [Reading](#Reading)
#
# 3. [Writing](#Writing)
#
# 4. [Native accessors](#Native-accessors)
#
# 5. [Indexing](#Indexing)
#
# 6. [Manipulating the index](#Manipulating-the-index)
#
# 7. [Conditional selection](#Conditional-selection)
#
# 8. [Assigning data](#Assigning-data)
#
# 9. [Summary functions](#Summary-functions)
#
# 10. [Maps](#Maps)
#
# 11. [Groupwise analysis](#Groupwise-analysis)
#
# 12. [Multi-indexes](#Multi-indexes)
#
# 13. [Sorting](#Sorting)
#
# 14. [Dtypes](#Dtypes)
#
# 15. [Missing data](#Missing-data)
#
# 16. [Renaming](#Renaming)
#
# 17. [Combining](#Combining)
#
# ***

# %% [markdown]
# ## Creating

# %%
# import pandas
import pandas as pd

# for short view
pd.set_option("display.max_rows", 5)

# %% [markdown]
# There are two core objects in pandas: the DataFrame and the Series.
# Each column in a DataFrame is a Series.
#
#
# Here examples of creation:
#
# |Dataframe|Series|
# |---------|------|
# |pd.DataFrame()|pd.Series()|

# %%
# Create simple dataframe
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
# add custom index in dataframe
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %%
# create a simple series
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# add custom index in series and name of series
## series does not have a column name, it only has one overall name
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'],
          name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %% [markdown]
# ## Reading

# %%
# read df
wine_reviews = pd.read_csv('./data/wines/winemag-data-130k-v2.csv')

# json
reviews =  pd.read_json('./data/wines/winemag-data-130k-v2.json')

# %%
# check shape of df
wine_reviews.shape
# Out:
# (129971, 14)

# %%
# show preview
wine_reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
# read df and set index-column
## index_col - attr for set of index-column
wine_reviews = pd.read_csv('./data/wines/winemag-data-130k-v2.csv', index_col=0)
reviews = wine_reviews
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %% [markdown]
# ## Writing

# %%
# for writing in pandas you should use method pd.to_csv (or to_xlsx, etc)
wine_reviews.to_csv('./data/wines/save_wines.csv')

# %% [markdown]
# ## Native accessors

# %%
# Native Python objects provide good ways of indexing data.
## Consider this DataFrame:
wine_reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
# get one column (pd.Series)
wine_reviews.country
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
# also u can get one column by this
wine_reviews['country']
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %% [markdown]
# ## Indexing
#
# The indexing operator and attribute selection are nice because they work just like they do in the rest of the Python ecosystem. As a novice, this makes them easy to pick up and use. However, pandas has its own accessor operators, loc and iloc. For more advanced operations, these are the ones you're supposed to be using.
#
# |iloc|loc|
# |-|-|
# |Index-based selection | Label-based selection|
# Selecting data **based on its numerical position in the data**| The **data index value, not its position**, which matters |
# |**iloc** uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded. **So 0:10 will select entries 0,...,9**|**loc**, meanwhile, indexes inclusively. **So 0:10 will select entries 0,...,10**|
#
# iloc is conceptually simpler than loc because it ignores the dataset's indices. When we use iloc we treat the dataset like a big matrix (a list of lists), one that we have to index into by position. loc, by contrast, uses the information in the indices to do its work. Since your dataset usually has meaningful indices, it's usually easier to do things using loc instead.

# %% [markdown]
# #### Index-based selection (iloc)

# %%
# get first row
wine_reviews.iloc[0]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %%
# get first column
wine_reviews.iloc[:, 0]
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
# get first 3 row in first column
wine_reviews.iloc[:3, 0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
wine_reviews.iloc[1:3, 0]
# Out:
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
# index like a list
wine_reviews.iloc[[0, 1, 2], 0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
# get last 5 rows
wine_reviews.iloc[-5:]
# Out:
#         country                                        description  \
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# ...

# %% [markdown]
# #### Label-based selection (loc)

# %%
# get country in first row
reviews.loc[0, 'country']
# Out:
# 'Italy'

# %%
# get current columns
reviews.loc[:, ['taster_name', 'taster_twitter_handle', 'points']]
# Out:
#           taster_name taster_twitter_handle  points
# 0       Kerin O’Keefe          @kerinokeefe      87
# 1          Roger Voss            @vossroger      87
# ...               ...                   ...     ...
# 129969     Roger Voss            @vossroger      90
# 129970     Roger Voss            @vossroger      90
#
# [129971 rows x 3 columns]

# %% [markdown]
# ## Manipulating the index

# %%
# set index
reviews.set_index("title")
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# ...                                                      ...
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       This is ripe and fruity, a wine that is smooth...
# ...                                                                                               ...
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)       A dry style of Pinot Gris, this is crisp with ...
# ...

# %% [markdown]
# ## Conditional selection
#
# > & - to bring the two questions together (logical and)
#
# > | - logical or
#
# Pandas comes with a few built-in conditional selectors, two of which we will highlight here.
#
# > **isin** is lets you select data whose value "is in" a list of values.
#
# > The second is **isnull** (and its companion **notnull**). These methods let you highlight values which are (or are not) empty (NaN)

# %%
## simple condition (by country)
reviews.country == 'Italy'
# Out:
# 0          True
# 1         False
#           ...
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
## filtering table
reviews.loc[reviews.country == 'Italy']
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  region_1  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna
# 6                         Belsito      87   16.0  Sicily & Sardinia  Vittoria
# ...                           ...     ...    ...                ...       ...
# 129961                        NaN      90   30.0  Sicily & Sardinia   Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia   Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
# We can use the ampersand (&) to bring the two questions together:
reviews.loc[(reviews.country == 'Italy') & (reviews.points >= 90)]
# Out:
#        country                                        description  \
# 120      Italy  Slightly backward, particularly given the vint...
# 130      Italy  At the first it was quite muted and subdued, b...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province region_1  \
# 120           Bricco Rocche Prapó      92   70.0           Piedmont   Barolo
# 130         Bricco Rocche Brunate      91   70.0           Piedmont   Barolo
# ...                           ...     ...    ...                ...      ...
# 129961                        NaN      90   30.0  Sicily & Sardinia  Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia  Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
# Suppose we'll buy any wine that's made in Italy or which is rated above average.
reviews.loc[(reviews.country == 'Italy') | (reviews.points >= 90)]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6                             Belsito      87   16.0  Sicily & Sardinia
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#         region_1 region_2    taster_name taster_twitter_handle  \
# 0           Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
# use isin 
reviews.loc[reviews.country.isin(['Italy', 'France'])]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6                             Belsito      87   16.0  Sicily & Sardinia
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#         region_1 region_2    taster_name taster_twitter_handle  \
# 0           Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
# use isnull|notnull
reviews.loc[reviews.price.notnull()]
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price province  \
# 1                            Avidagos      87   15.0    Douro
# 2                                 NaN      87   14.0   Oregon
# ...                               ...     ...    ...      ...
# 129969                            NaN      90   32.0   Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#                  region_1           region_2   taster_name  \
# 1                     NaN                NaN    Roger Voss
# 2       Willamette Valley  Willamette Valley  Paul Gregutt
# ...

# %% [markdown]
# ## Assigning data

# %%
# assign all column
reviews['critic'] = 'everyone'
reviews['critic']
# Out:
# 0         everyone
# 1         everyone
#             ...
# 129969    everyone
# 129970    everyone
# Name: critic, Length: 129971, dtype: object

# %%
# with iterable of values
reviews['index_backwards'] = range(len(reviews), 0, -1)
reviews['index_backwards']
# Out:
# 0         129971
# 1         129970
#            ...
# 129969         2
# 129970         1
# Name: index_backwards, Length: 129971, dtype: int64

# %%
# drop table and reset to standard
reviews = pd.read_csv('./data/wines/winemag-data-130k-v2.csv', index_col=0)

# %% [markdown]
# ## Summary functions

# %% [markdown]
# Pandas provides many simple "summary functions" (not an official name) which restructure the data in some useful way.
#
# > describe()
#
# > mean()
#
# > unique()
#
# > value_counts()

# %%
# For example, consider the describe() method:
reviews.describe()
# Out:
#               points          price
# count  129971.000000  120975.000000
# mean       88.447138      35.363389
# ...              ...            ...
# 75%        91.000000      42.000000
# max       100.000000    3300.000000
#
# [8 rows x 2 columns]

# %%
# describe a column 
reviews.taster_name.describe()
# Out:
# count         103727
# unique            19
# top       Roger Voss
# freq           25514
# Name: taster_name, dtype: object

# %%
# check mean
reviews.points.mean()
# Out:
# 88.44713820775404

# %%
# get list of unique values
reviews.taster_name.unique()
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
# get list of unique values and how often they occur if df
reviews.taster_name.value_counts()
# Out:
# Roger Voss           25514
# Michael Schachner    15134
#                      ...
# Fiona Adams             27
# Christina Pickard        6
# Name: taster_name, Length: 19, dtype: int64

# %% [markdown]
# ## Maps

# %% [markdown]
# A map is a term, borrowed from mathematics, for a function that takes one set of values and "maps" them to another set of values. In data science we often have a need for creating new representations from existing data, or for transforming data from the format it is in now to the format that we want it to be in later. Maps are what handle this work, making them extremely important for getting your work done!
#
# There are two mapping methods that you will use often.

# %% [markdown]
# **map()** is the first, and slightly simpler one. For example, suppose that we wanted to remean the scores the wines received to 0. We can do this as follows:

# %%
review_points_mean = reviews.points.mean()
reviews.points.map(lambda p: p - review_points_mean)
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %% [markdown]
# The function you pass to map() should expect a single value from the Series (a point value, in the above example), and return a transformed version of that value. map() returns a new Series where all the values have been transformed by your function.

# %% [markdown]
# **apply()** is the equivalent method **if we want to transform a whole DataFrame** by calling a custom method on each row.

# %%
def remean_points(row):
    row.points = row.points - review_points_mean
    return row

reviews.apply(remean_points, axis='columns')
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation    points  price           province  \
# 0                        Vulkà Bianco -1.447138    NaN  Sicily & Sardinia
# 1                            Avidagos -1.447138   15.0              Douro
# ...                               ...       ...    ...                ...
# 129969                            NaN  1.552862   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline  1.552862   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %% [markdown]
# *If we had called reviews.apply() with axis='index', then instead of passing a function to transform each row, we would need to give a function to transform each column.*

# %% [markdown]
# Note that **map() and apply() return new, transformed Series and DataFrames, respectively. They don't modify the original data they're called on**. If we look at the first row of reviews, we can see that it still has its original points value.

# %%
reviews.head(1)
# Out:
#   country                                        description   designation  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
#
#   taster_twitter_handle                              title      variety  \
# 0          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)  White Blend
#
#     winery
# 0  Nicosia

# %% [markdown]
# Pandas provides many common mapping operations as built-ins. For example, here's a faster way of remeaning our points column:

# %%
review_points_mean = reviews.points.mean()
reviews.points - review_points_mean
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
reviews.country + " - " + reviews.region_1
# Out:
# 0            Italy - Etna
# 1                     NaN
#                ...
# 129969    France - Alsace
# 129970    France - Alsace
# Length: 129971, dtype: object

# %% [markdown]
# ## Groupwise analysis
#
# One function we've been using heavily thus far is the `value_counts()` function. We can replicate what `value_counts()` does by doing the following:

# %%
# replicate value_counts() like groupby
reviews.groupby('points').points.count()
# Out:
# points
# 80     397
# 81     692
#       ...
# 99      33
# 100     19
# Name: points, Length: 21, dtype: int64

# %% [markdown]
# `groupby()` created a group of reviews which allotted the same point values to the given wines. Then, for each of these groups, we grabbed the `points()` column and counted how many times it appeared. `value_counts()` is just a shortcut to this `groupby()` operation.
#
# We can use any of the summary functions we've used before with this data. For example, to get the cheapest wine in each point value category, we can do the following:

# %%
# groupby by points with minimal price
reviews.groupby('points').price.min()
# Out:
# points
# 80      5.0
# 81      5.0
#        ...
# 99     44.0
# 100    80.0
# Name: price, Length: 21, dtype: float64

# %% [markdown]
# You can think of each group we generate as being a slice of our DataFrame containing only data with values that match. This DataFrame is accessible to us directly using the apply() method, and we can then manipulate the data in any way we see fit. For example, here's one way of selecting the name of the first wine reviewed from each winery in the dataset:

# %%
reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
# Out:
# winery
# 1+1=3                          1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                 10 Knots 2010 Viognier (Paso Robles)
#                                   ...
# àMaurice    àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                         Štoka 2009 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %% [markdown]
# For even more fine-grained control, you can also group by more than one column. For an example, here's how we would pick out the best wine by country and province:

# %%
reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])
# Out:
#                               country  \
# country   province
# Argentina Mendoza Province  Argentina
#           Other             Argentina
# ...                               ...
# Uruguay   San Jose            Uruguay
#           Uruguay             Uruguay
#
#                                                                   description  \
# country   province
# Argentina Mendoza Province  If the color doesn't tell the full story, the ...
#           Other             Take note, this could be the best wine Colomé ...
# ...                                                                       ...
# Uruguay   San Jose          Baked, sweet, heavy aromas turn earthy with ti...
#           Uruguay           Cherry and berry aromas are ripe, healthy and ...
#
#                                           designation  points  price  \
# country   province
# Argentina Mendoza Province           Nicasia Vineyard      97  120.0
# ...

# %% [markdown]
# Another groupby() method worth mentioning is agg(), which lets you run a bunch of different functions on your DataFrame simultaneously. For example, we can generate a simple statistical summary of the dataset as follows:

# %%
reviews.groupby(['country']).price.agg([len, min, max])
# Out:
#             len   min    max
# country
# Argentina  3800   4.0  230.0
# Armenia       2  14.0   15.0
# ...         ...   ...    ...
# Ukraine      14   6.0   13.0
# Uruguay     109  10.0  130.0
#
# [43 rows x 3 columns]

# %% [markdown]
# ## Multi-indexes
#
# in all of the examples we've seen thus far we've been working with DataFrame or Series objects with a single-label index. groupby() is slightly different in the fact that, depending on the operation we run, it will sometimes result in what is called a multi-index.
#
# A multi-index differs from a regular index in that it has multiple levels. For example:

# %%
countries_reviewed = reviews.groupby(['country', 'province']).description.agg([len])
countries_reviewed
# Out:
#                              len
# country   province
# Argentina Mendoza Province  3264
#           Other              536
# ...                          ...
# Uruguay   San Jose             3
#           Uruguay             24
#
# [425 rows x 1 columns]

# %%
countries_reviewed = reviews.groupby(['country', 'province']).price.agg([min, max, len])
countries_reviewed
# Out:
#                              min    max   len
# country   province
# Argentina Mendoza Province   4.0  230.0  3264
#           Other              7.0  150.0   536
# ...                          ...    ...   ...
# Uruguay   San Jose          20.0   50.0     3
#           Uruguay           12.0   50.0    24
#
# [425 rows x 3 columns]

# %%
mi = countries_reviewed.index
type(mi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
# get element with multi-index
countries_reviewed.loc[('Argentina', 'Mendoza Province'), 'min']
# Out:
# 4.0

# %% [markdown]
# Multi-indices have several methods for dealing with their tiered structure which are absent for single-level indices. They also require two levels of labels to retrieve a value. Dealing with multi-index output is a common "gotcha" for users new to pandas.
#
# The use cases for a multi-index are detailed alongside instructions on using them in the [MultiIndex / Advanced Selection section of the pandas documentation.](https://pandas.pydata.org/pandas-docs/stable/user_guide/advanced.html#hierarchical-indexing-multiindex)
#
# However, in general the multi-index method you will use most often is the one for converting back to a regular index, the `reset_index()` method:

# %%
countries_reviewed.reset_index()
# Out:
#        country          province   min    max
# 0    Argentina  Mendoza Province   4.0  230.0
# 1    Argentina             Other   7.0  150.0
# ..         ...               ...   ...    ...
# 423    Uruguay          San Jose  20.0   50.0
# 424    Uruguay           Uruguay  12.0   50.0
#
# [425 rows x 4 columns]

# %% [markdown]
# ## Sorting

# %%
# simple sorting
countries_reviewed = countries_reviewed.reset_index()
countries_reviewed.sort_values(by='min')
# Out:
#           country          province  min    max   len
# 0       Argentina  Mendoza Province  4.0  230.0  3264
# 372         Spain     Central Spain  4.0  250.0   485
# ..            ...               ...  ...    ...   ...
# 335  South Africa     Ceres Plateau  NaN    NaN     1
# 357  South Africa   Piekenierskloof  NaN    NaN     1
#
# [425 rows x 5 columns]

# %% [markdown]
# `sort_values()` defaults to an ascending sort, where the lowest values go first. However, most of the time we want a descending sort, where the higher numbers go first. That goes thusly:

# %%
countries_reviewed.sort_values(by='len', ascending=False)
# Out:
#     country    province   min     max    len
# 392      US  California   4.0  2013.0  36247
# 415      US  Washington   6.0   240.0   8639
# ..      ...         ...   ...     ...    ...
# 63    Chile     Coelemu  25.0    25.0      1
# 149  Greece      Beotia  27.0    27.0      1
#
# [425 rows x 5 columns]

# %% [markdown]
# To sort by index values, use the companion method sort_index(). This method has the same arguments and default order:

# %%
countries_reviewed.sort_index()
# Out:
#        country          province   min    max   len
# 0    Argentina  Mendoza Province   4.0  230.0  3264
# 1    Argentina             Other   7.0  150.0   536
# ..         ...               ...   ...    ...   ...
# 423    Uruguay          San Jose  20.0   50.0     3
# 424    Uruguay           Uruguay  12.0   50.0    24
#
# [425 rows x 5 columns]

# %%
# sorting by more than one column
countries_reviewed.sort_values(by=['country', 'len'])
# Out:
#        country          province   min    max   len
# 1    Argentina             Other   7.0  150.0   536
# 0    Argentina  Mendoza Province   4.0  230.0  3264
# ..         ...               ...   ...    ...   ...
# 424    Uruguay           Uruguay  12.0   50.0    24
# 419    Uruguay         Canelones  12.0   65.0    43
#
# [425 rows x 5 columns]

# %% [markdown]
# ## Dtypes
#
# The data type for a column in a DataFrame or a Series is known as the **dtype**.
#
# You can use the `dtype` property to grab the type of a specific column. For instance, we can get the dtype of the price column in the reviews DataFrame:

# %%
# check type of price column in reviews
reviews.price.dtype
# Out:
# dtype('float64')

# %% [markdown]
# like `dtype`, `dtypes` show type of each series

# %%
# dtype of every column
reviews.dtypes
# Out:
# country        object
# description    object
#                 ...
# variety        object
# winery         object
# Length: 13, dtype: object

# %% [markdown]
# for convert types - `astype()`

# %%
# convert int64 to float64
reviews.points.astype('float64')
# Out:
# 0         87.0
# 1         87.0
#           ...
# 129969    90.0
# 129970    90.0
# Name: points, Length: 129971, dtype: float64

# %%
# index have type too
reviews.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## Missing data

# %% [markdown]
# Entries missing values are given the value `NaN`, short for "Not a Number". For technical reasons these NaN values are always of the `float64` dtype.

# %%
# filter df by country NaN
reviews[pd.isnull(reviews.country)]
# Out:
#        country                                        description  \
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# ...        ...                                                ...
# 129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900     NaN  This wine offers a delightful bouquet of black...
#
#            designation  points  price province region_1 region_2  \
# 913     Asureti Valley      87   30.0      NaN      NaN      NaN
# 3131          Partager      83    NaN      NaN      NaN      NaN
# ...                ...     ...    ...      ...      ...      ...
# 129590            Shah      90   30.0      NaN      NaN      NaN
# 129900             NaN      91   32.0      NaN      NaN      NaN
#
#           taster_name taster_twitter_handle  \
# 913     Mike DeSimone        @worldwineguys
# 3131       Roger Voss            @vossroger
# ...

# %% [markdown]
# Replacing missing values is a common operation.  Pandas provides a really handy method for this problem: `fillna()`. `fillna()` provides a few different strategies for mitigating such data. For example, we can simply replace each `NaN` with an `"Unknown"`:

# %%
reviews.region_2.fillna("Unknown")
# Out:
# 0         Unknown
# 1         Unknown
#            ...
# 129969    Unknown
# 129970    Unknown
# Name: region_2, Length: 129971, dtype: object

# %% [markdown]
# Or we could fill each missing value with the first non-null value that appears sometime after the given record in the database. This is known as the backfill strategy.

# %% [markdown]
# Alternatively, we may have a non-null value that we would like to replace. For example, suppose that since this dataset was published, reviewer Kerin O'Keefe has changed her Twitter handle from `@kerinokeefe` to `@kerino`. One way to reflect this in the dataset is using the `replace()` method:

# %%
reviews.taster_twitter_handle.replace("@kerinokeefe", "@kerino")
# Out:
# 0            @kerino
# 1         @vossroger
#              ...
# 129969    @vossroger
# 129970    @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: object

# %% [markdown]
# ## Renaming

# %% [markdown]
# The first function we'll introduce here is `rename()`, which lets you change index names and/or column names

# %%
reviews.rename(columns={'points': 'score'})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  score  price           province  \
# 0                        Vulkà Bianco     87    NaN  Sicily & Sardinia
# 1                            Avidagos     87   15.0              Douro
# ...                               ...    ...    ...                ...
# 129969                            NaN     90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline     90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# 0          Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %% [markdown]
# rename() lets you rename index or column values by specifying a index or column keyword parameter, respectively. It supports a variety of input formats, but usually a Python dictionary is the most convenient. Here is an example using it to rename some elements of the index.

# %%
reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#               country                                        description  \
# firstEntry      Italy  Aromas include tropical fruit, broom, brimston...
# secondEntry  Portugal  This is ripe and fruity, a wine that is smooth...
# ...               ...                                                ...
# 129969         France  A dry style of Pinot Gris, this is crisp with ...
# 129970         France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# firstEntry                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# secondEntry                       Avidagos      87   15.0              Douro
# ...                                    ...     ...    ...                ...
# 129969                                 NaN      90   32.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
# ...

# %% [markdown]
# You'll probably rename columns very often, but rename index values very rarely. For that, `set_index()` is usually more convenient.
#
# Both the row index and the column index can have their own name attribute. The complimentary `rename_axis()` method may be used to change these names. For example:

# %%
reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields   country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
# fields                    designation  points  price           province  \
# wines
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
# fields region_1 region_2    taster_name taster_twitter_handle  \
# wines
# ...

# %% [markdown]
# ## Combining

# %% [markdown]
# When performing operations on a dataset, we will sometimes need to combine different DataFrames and/or Series in non-trivial ways. Pandas has three core methods for doing this. In order of increasing complexity, these are `concat()`, `join()`, and `merge()`. Most of what `merge()` can do can also be done more simply with `join()`, so we will omit it and focus on the first two functions here.
#
# The simplest combining method is `concat()`. Given a list of elements, this function will smush those elements together along an axis.

# %%
canadian_youtube = pd.read_csv("./data/wines/CAvideos.csv")
british_youtube = pd.read_csv("./data/wines/GBvideos.csv")

pd.concat([canadian_youtube, british_youtube])
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# ...            ...           ...
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                          PLUSH - Bad Unboxing Fan Mail
# ...                                                  ...
# 38914  Eleni Foureira - Fuego - Cyprus - LIVE - First...
# 38915  KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...
#
#                  channel_title  category_id              publish_time  \
# 0                   EminemVEVO           10  2017-11-10T17:00:03.000Z
# 1                    iDubbbzTV           23  2017-11-13T17:00:00.000Z
# ...                        ...          ...                       ...
# 38914  Eurovision Song Contest           24  2018-05-08T20:32:32.000Z
# ...

# %%
print('df CA shape {}\ndf GB shape {}'.format(canadian_youtube.shape, british_youtube.shape))
# Out:
# df CA shape (40881, 16)
# df GB shape (38916, 16)

# %% [markdown]
# The middlemost combiner in terms of complexity is join(). join() lets you combine different DataFrame objects which have an index in common. For example, to pull down videos that happened to be trending on the same day in both Canada and the UK, we could do the following:

# %%
left = canadian_youtube.set_index(['title', 'trending_date'])
right = british_youtube.set_index(['title', 'trending_date'])

left.join(right, lsuffix='_CAN', rsuffix='_UK')
# Out:
#                                                                  video_id_CAN  \
# title                                              trending_date
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ... 18.04.01       PNn8sECd7io
# #1 Fortnite World Rank - 2,323 Solo Wins!          18.09.03       DvPW66IFhMI
# ...                                                                       ...
# 🚨 BREAKING NEWS 🔴 Raja Live all Slot Channels W... 18.07.05       Wt9Gkpmbt44
# 🚨Active Shooter at YouTube Headquarters - LIVE ... 18.04.04       Az72jrKbANA
#
#                                                                                 channel_title_CAN  \
# title                                              trending_date
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ... 18.04.01                            Markiplier
# #1 Fortnite World Rank - 2,323 Solo Wins!          18.09.03                        AlexRamiGaming
# ...

# %% [markdown]
# The lsuffix and rsuffix parameters are necessary here because the data has the same column names in both British and Canadian datasets. If this wasn't true (because, say, we'd renamed them beforehand) we wouldn't need them.
